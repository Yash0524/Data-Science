# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash0524/Data-Science/blob/main/CreditCardFraudDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Data Visualization & Data Analysis

# %%
df.Class.value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
a = df.drop('Class', axis = 1)
b = df.Class
legal = df[df.Class == 0]
fraud = df[df.Class == 1]
print(a)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
print(b)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %%
print(legal.shape)
# Out:
# (283253, 31)

# %%
print(fraud.shape)
# Out:
# (473, 31)

# %%
legal.Amount.describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94835.058093  0.013439 -0.009829  0.012853 -0.010440  0.006769
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.001251  0.010447 -0.002448  0.002613  ... -0.000489 -0.00115
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.46655
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000160  0.000360  0.000393 -0.000301  0.000065  0.001409  0.000418
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       88.413575
# 1      123.871860
#
# [2 rows x 30 columns]

# %% [markdown]
# **Segregating Targets and Features**

# %%
x = df.drop('Class', axis = 1)
y = df.Class
print(x)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
print(y)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %% [markdown]
# **Importing Libraries for Model Training**

# %% [markdown]
# ## **Importing Libraries for Model Training**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score

# %% [markdown]
# ## **Model Training**

# %%
df = df.dropna()
x = df.drop('Class', axis = 1)
y = df.Class

x_tr, x_ts, y_tr, y_ts = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 2)

# %%
print(x_tr.shape, x_ts.shape, y_tr.shape, y_ts.shape)
# Out:
# (226980, 30) (56746, 30) (226980,) (56746,)

# %%
m = LogisticRegression()
m.fit(x_tr, y_tr)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_tr_pred = m.predict(x_tr)
tr_acc = accuracy_score(x_tr_pred, y_tr)
print("Accuracy on Training data : ", tr_acc)
# Out:
# Accuracy on Training data :  0.9989690721649485

# %%
x_ts_pred = m.predict(x_ts)
ts_acc = accuracy_score(x_ts_pred, y_ts)
print("Accuracy on Testing data : ", ts_acc)
# Out:
# Accuracy on Testing data :  0.999066013463504

# %%
print("Precision score on Testing data : ", precision_score(y_ts, x_ts_pred) * 100)
# Out:
# Precision score on Testing data :  73.33333333333333

# %%
sample = m.predict(x_ts)
print("Legal" if (sample[0] == 0) else "Fraud")
# Out:
# Legal

# %% [markdown]
# # **Let's increase the precision by under sampling**

# %%
print(legal.shape, fraud.shape)
# Out:
# (283253, 31) (473, 31)

# %%
ns = legal.sample(n = 201)
print(ns.shape)
# Out:
# (201, 31)

# %%
print(ns)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 119636   75527.0  1.028360  0.616442  0.136596  2.708796  0.020779 -0.725892
# 12840    22548.0  1.169834  0.017381  0.836739  1.035206 -0.671919 -0.362198
# 53104    45815.0 -0.338406  1.012710  1.257358  0.076558 -0.124794 -1.020693
# 146655   87804.0 -0.878162  1.525209  0.211650 -0.632859  1.077997 -0.369169
# 12831    22526.0 -0.947464  0.163629  2.110260 -2.604020 -0.706120  0.049503
# ...          ...       ...       ...       ...       ...       ...       ...
# 143870   85690.0 -1.308220  1.115940  0.276204 -0.213911  0.079860 -0.376929
# 283971  172047.0  2.097614 -0.694442 -1.160582 -0.732355 -0.616122 -0.512145
# 117750   74794.0 -1.824189  1.300776  0.321145  0.521576 -0.336653 -0.635813
# 33593    37297.0 -0.624406  0.964614  1.541440  0.993074  0.365310 -1.088046
# 217953  141106.0 -0.827609  1.046543  1.023643 -0.420738  1.051046 -0.314449
#
# ...

# %%
ndf = pd.concat([ns, fraud], axis = 0)
ndf = ndf.drop('Time', axis = 1)
ndf.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 119636  1.028360  0.616442  0.136596  2.708796  0.020779 -0.725892  0.372506
# 12840   1.169834  0.017381  0.836739  1.035206 -0.671919 -0.362198 -0.373648
# 53104  -0.338406  1.012710  1.257358  0.076558 -0.124794 -1.020693  0.595787
# 146655 -0.878162  1.525209  0.211650 -0.632859  1.077997 -0.369169  1.186441
# 12831  -0.947464  0.163629  2.110260 -2.604020 -0.706120  0.049503 -0.378988
#
#               V8        V9       V10  ...       V21       V22       V23  \
# 119636 -0.162860 -0.844452  0.169324  ... -0.207762 -0.823896 -0.002017
# 12840  -0.005412  1.745210 -0.393025  ... -0.182634 -0.105628 -0.054807
# 53104   0.024617 -0.134310 -0.460800  ... -0.284567 -0.830747  0.002934
# 146655 -0.310175 -0.209682  0.111994  ... -0.295928 -0.628637 -0.105543
# 12831  -0.120697 -0.336931  1.248610  ... -0.333166  0.099549 -0.334823
#
# ...

# %%
ndf.tail()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 279863 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 280143  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 280149 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 281144 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 281674  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
#               V8        V9       V10  ...       V21       V22       V23  \
# 279863  0.697211 -2.064945 -5.587794  ...  0.778584 -0.319189  0.639419
# 280143  0.248525 -1.127396 -3.232153  ...  0.370612  0.028234 -0.145640
# 280149  1.210158 -0.652250 -3.463891  ...  0.751826  0.834108  0.190944
# 281144  1.058733 -1.632333 -5.245984  ...  0.583276 -0.269209 -0.456108
# 281674 -0.068384  0.577829 -0.888722  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
x = ndf.drop("Class", axis = 1)
y = ndf["Class"]
X_tr, X_ts, Y_tr, Y_ts = train_test_split(x, y, test_size = 0.2, random_state = 2)
print(X_tr.shape, X_ts.shape, Y_tr.shape, Y_ts.shape)
# Out:
# (539, 29) (135, 29) (539,) (135,)

# %%
m = LogisticRegression()

# %%
m.fit(X_tr, Y_tr)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_tr_pred = m.predict(X_tr)
tr_acc = accuracy_score(X_tr_pred, Y_tr)

# %%
print("Accuracy on Training data : ", tr_acc)
# Out:
# Accuracy on Training data :  0.9424860853432282

# %%
X_ts_pred = m.predict(X_ts)
ts_acc = accuracy_score(X_ts_pred, Y_ts)

# %%
print("Accuracy on Testing data : ", ts_acc)
# Out:
# Accuracy on Testing data :  0.9333333333333333

# %%
print("Precision score on Testing data : ", precision_score(Y_ts, X_ts_pred) * 100)
# Out:
# Precision score on Testing data :  94.6236559139785

# %%
pred = m.predict(X_ts)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
